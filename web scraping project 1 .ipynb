# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # 1. Write a python program to display all the header tags from‘en.wikipedia.org/wiki/Main_Page’.

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page')
# page

# %%
page.content

soup=BeautifulSoup(page.content)

soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Wikipedia, the free encyclopedia\n  </title>\n  <script>\n   document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"cd1de986-e480-4117-8706-0f72012e2074","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1004593520,"wgRevisionId":1004593520,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbabl
# ...

# %% [markdown]
# # H1

# %%
Head=soup.find_all(['h1'])
Head
# Out:
# [<h1 class="firstHeading" id="firstHeading">Main Page</h1>]

# %%
s=[]

for i in Head:
    s.append(i.text.replace('\n',''))
s
# Out:
# ['Main Page']

# %%
H1=pd.DataFrame()

H1['H1']=s

# %% [markdown]
# # H2

# %%
Head=soup.find_all(['h2'])

# %%
s=[]

for i in Head:
    s.append(i.text.replace('\n',''))
s
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "From today's featured list",
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Navigation menu']

# %%
H2=pd.DataFrame()

H2['H2']=s

# %% [markdown]
# # H3

# %%
Head=soup.find_all(['h3'])

# %%
s=[]

for i in Head:
    s.append(i.text.replace('\n',''))
s
# Out:
# ['Personal tools',
#  'Namespaces',
#  'Variants',
#  'Views',
#  'More',
#  'Search',
#  'Navigation',
#  'Contribute',
#  'Tools',
#  'Print/export',
#  'In other projects',
#  'Languages']

# %%
H3=pd.DataFrame()

H3['H3']=s

# %% [markdown]
# # H4

# %%
Head=soup.find_all(['h4'])

# %%
s=[]

for i in Head:
    s.append(i.text.replace('\n',''))
s
# Out:
# []

# %%
H4=pd.DataFrame()

H4['H4']=s

# %% [markdown]
# # RESULT

# %%
result=pd.concat([H1,H2,H3,H4.reindex(H1.index)], axis=1)
print(result)
# Out:
#            H1                             H2                 H3  H4
# 0   Main Page  From today's featured article     Personal tools NaN
# 1         NaN               Did you know ...         Namespaces NaN
# 2         NaN                    In the news           Variants NaN
# 3         NaN                    On this day              Views NaN
# 4         NaN     From today's featured list               More NaN
# 5         NaN       Today's featured picture             Search NaN
# 6         NaN       Other areas of Wikipedia         Navigation NaN
# 7         NaN    Wikipedia's sister projects         Contribute NaN
# 8         NaN            Wikipedia languages              Tools NaN
# 9         NaN                Navigation menu       Print/export NaN
# 10        NaN                            NaN  In other projects NaN
# 11        NaN                            NaN          Languages NaN

# %% [markdown]
# # 2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release).

# %%
page=requests.get("https://www.imdb.com/chart/top/?ref_=nv_mv_250 ")

# %%
page.content
soup=BeautifulSoup(page.content)

# %% [markdown]
# # movie

# %%
movie=soup.find_all('td',class_="titleColumn")

# %%
series_name=[]

for i in movie:
    series_name.append(i.text.replace('\n',""))

# %%
H1=pd.DataFrame()
H1['movie_name']=series_name[:100]
print(H1)
# Out:
#                                            movie_name
# 0              1.      The Shawshank Redemption(1994)
# 1                         2.      The Godfather(1972)
# 2                3.      The Godfather: Part II(1974)
# 3                       4.      The Dark Knight(2008)
# 4                          5.      12 Angry Men(1957)
# ..                                                ...
# 95                              96.      Jagten(2012)
# 96                 97.      Requiem for a Dream(2000)
# 97                 98.      Singin' in the Rain(1952)
# 98                  99.      North by Northwest(1959)
# 99        100.      Eternal Sunshine of the Spotle...
#
# [100 rows x 1 columns]

# %% [markdown]
# # rating

# %%
rating=soup.find_all('td',class_="ratingColumn imdbRating")

# %%
series_name=[]

for i in rating:
    series_name.append(i.text.replace('\n',""))

# %%
H2=pd.DataFrame()
H2['rating']=series_name[:100]
H2
# Out:
#    rating
# 0     9.2
# 1     9.1
# 2     9.0
# 3     9.0
# 4     8.9
# ..    ...
# 95    8.3
# 96    8.3
# 97    8.3
# 98    8.3
# 99    8.3
#
# [100 rows x 1 columns]

# %%
result=pd.concat([H1,H2.reindex(H1.index)], axis=1)
result
# Out:
#                                            movie_name rating
# 0              1.      The Shawshank Redemption(1994)    9.2
# 1                         2.      The Godfather(1972)    9.1
# 2                3.      The Godfather: Part II(1974)    9.0
# 3                       4.      The Dark Knight(2008)    9.0
# 4                          5.      12 Angry Men(1957)    8.9
# ..                                                ...    ...
# 95                              96.      Jagten(2012)    8.3
# 96                 97.      Requiem for a Dream(2000)    8.3
# 97                 98.      Singin' in the Rain(1952)    8.3
# 98                  99.      North by Northwest(1959)    8.3
# 99        100.      Eternal Sunshine of the Spotle...    8.3
#
# [100 rows x 2 columns]

# %% [markdown]
# # 3. Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release).

# %%
page=requests.get("https://www.imdb.com/india/top-rated-indian-movies/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=8a7876cd-2844-4017-846a-2c0876945b7b&pf_rd_r=3P2J4PTAZBNA0RTWM2PA&pf_rd_s=right-5&pf_rd_t=15506&pf_rd_i=moviemeter&ref_=chtmvm_india_tr_rhs_1")

page.content
soup=BeautifulSoup(page.content)

# movie

movie=soup.find_all('td',class_="titleColumn")

series_name=[]

for i in movie:
    series_name.append(i.text.replace('\n',""))

H1=pd.DataFrame()
H1['movie_name&year']=series_name[:100]
H1
# Out:
#                                       movie_name&year
# 0                               1.      Nayakan(1987)
# 1                            2.      Anbe Sivam(2003)
# 2                     3.      Pariyerum Perumal(2018)
# 3                     4.      C/o Kancharapalem(2018)
# 4                               5.      Golmaal(1979)
# ..                                                ...
# 95                     96.      Rang De Basanti(2006)
# 96                                97.      Roja(1992)
# 97        98.      Lagaan: Once Upon a Time in Ind...
# 98            99.      Uri: The Surgical Strike(2019)
# 99                    100.      Andaz Apna Apna(1994)
#
# [100 rows x 1 columns]

# %% [markdown]
# # rating

# %%
rating=soup.find_all('td',class_="ratingColumn imdbRating")

series_name=[]

for i in rating:
    series_name.append(i.text.replace('\n',""))

H2=pd.DataFrame()
H2['rating']=series_name[:100]


result=pd.concat([H1,H2.reindex(H1.index)], axis=1)
result
# Out:
#                                       movie_name&year rating
# 0                               1.      Nayakan(1987)    8.5
# 1                            2.      Anbe Sivam(2003)    8.5
# 2                     3.      Pariyerum Perumal(2018)    8.5
# 3                     4.      C/o Kancharapalem(2018)    8.5
# 4                               5.      Golmaal(1979)    8.5
# ..                                                ...    ...
# 95                     96.      Rang De Basanti(2006)    8.1
# 96                                97.      Roja(1992)    8.1
# 97        98.      Lagaan: Once Upon a Time in Ind...    8.1
# 98            99.      Uri: The Surgical Strike(2019)    8.1
# 99                    100.      Andaz Apna Apna(1994)    8.1
#
# [100 rows x 2 columns]

# %% [markdown]
# # 4. Write a python program to scrap book name, author name, genre and book review of any 5 books from
# ‘www.bookpage.com’

# %%
page=requests.get('https://bookpage.com/features')
page.content
soup=BeautifulSoup(page.content)

# %% [markdown]
# # book_name

# %%
book=soup.find_all('h4',class_="italic")   
book
# Out:
# [<h4 class="italic">
#  <a href="/behind-the-book/26562-top-12-weirdest-moments-food-history-history">The top 12 weirdest moments in food history</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/features/26512-southern-kinship-fiction">A Southern kinship</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/behind-the-book/26626-five-romances-that-sparkle-with-fairy-tale-magic-romance">Five romances that sparkle with fairy-tale magic</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/features/26553-their-stories-changed-world-childrens">Their stories changed the world</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/features/26465-2021-preview-fall-finds">2021 preview: Fall finds</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/features/26513-not-simple-whodunit-mystery-suspense">Not a simple whodunit</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/features/26516-love-way-you-lie-mystery-suspense">Love the way you lie</a>
#  </h4>,
#  <h4 class="italic">
# ...

# %%
# we use loop for text 
book_name=[]

for i in book:
    for j  in i.find_all("a"):                     #we dont need year extra data
        book_name.append(j.text.replace('\n',''))               #  replace n for clean data
book_name
# Out:
# ['The top 12 weirdest moments in food history',
#  'A Southern kinship',
#  'Five romances that sparkle with fairy-tale magic',
#  'Their stories changed the world',
#  '2021 preview: Fall finds',
#  'Not a simple whodunit',
#  'Love the way you lie',
#  'Step aside, Homer',
#  'Cover reveal: ‘A Duet for Home’',
#  'Whodunit: August 2021']

# %% [markdown]
# # author_name

# %%
# author_name

first_title=soup.find_all('p',class_="sans bold")
                
author_name=[]

for i in first_title:
    author_name.append(i.text.replace('\n',''))

# %% [markdown]
# # genre

# %%
first_title=soup.find_all('p',class_="genre-links hidden-phone")

genre=[]

for i in first_title:
    genre.append(i.text.replace('\n',''))

# %% [markdown]
# # book_review

# %%
first_title=soup.find_all('p',class_='excerpt')#,class_="excerpt")

book_review=[]

for i in first_title:
    book_review.append(i.text.replace('\n',''))

# %%
# end report

# %%
w1=pd.DataFrame()
w1['Book_names']=book_name
w1

#web_series

w2=pd.DataFrame()
w2['Author_name']=author_name 
w2

w3=pd.DataFrame()
w3['Genre']=genre 
w3

w4=pd.DataFrame()
w4['Book_review']=book_review 
w4

pd.concat([w1, w2,w3,w4.reindex(w1.index)], axis=1)
# Out:
#                                          Book_names  \
# 0       The top 12 weirdest moments in food history
# 1                                A Southern kinship
# 2  Five romances that sparkle with fairy-tale magic
# 3                   Their stories changed the world
# 4                          2021 preview: Fall finds
# 5                             Not a simple whodunit
# 6                              Love the way you lie
# 7                                 Step aside, Homer
# 8                   Cover reveal: ‘A Duet for Home’
# 9                             Whodunit: August 2021
#
#                               Author_name  \
# 0          Behind the Book by Matt Siegel
# 1      Feature by Honorée Fanonne Jeffers
# 2      Behind the Book by Charis Michaels
# 3               Feature by Jill Lorenzini
# 4      Feature by the editors of BookPage
# 5               Feature by Naomi Hirahara
# 6               Feature by Heather Seggel
# 7                  Feature by Jill Ratzan
# ...

# %% [markdown]
# # 5. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have toscrape:
# i) Top 10 ODI teams in men’s cricket along with the records for matches, points andrating

# %%
import bs4

page=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')

page.content

soup=BeautifulSoup(page.content)

s1=soup.find_all('span',class_="u-hide-phablet")             

W1=[]
for i in s1:
    W1.append(i.text)

s2=soup.find_all('td',class_="table-body__cell u-center-text")              

W21=[]
for i in s2:
    W21.append(i.text)
W21

W2=W21[0:36:2]
W2

s3=soup.find_all('td',class_="table-body__cell u-text-right rating")

W31=[]
for i in s3:
    W31.append(i.text)

W3=W21[1:36:2]
W3

s4=soup.find_all('td',class_="table-body__cell u-text-right rating")

W4=[]
for i in s4:
    W4.append(i.text)

H1=pd.DataFrame()
H1['TEAM']=W1[1:10]

H2=pd.DataFrame()
H2['MATCH']=W2[0:10]

H3=pd.DataFrame()
H3['POINT']=W3[0:10]

H4=pd.DataFrame()
H4['RATING']=W4[0:10]

pd.concat([H1,H2,H3,H4.reindex(H1.index)], axis=1)
# Out:
#            TEAM MATCH  POINT RATING
# 0       England    32  3,793    119
# 1     Australia    28  3,244    116
# 2         India    32  3,624    113
# 3  South Africa    22  2,267    103
# 4      Pakistan    27  2,524     93
# 5    Bangladesh    29  2,639     91
# 6   West Indies    30  2,523     84
# 7     Sri Lanka    29  2,303     79
# 8   Afghanistan    17  1,054     62
# 9           NaN     7    336    NaN

# %% [markdown]
# ii) Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')

page.content

soup=BeautifulSoup(page.content)

s1=soup.find_all('td',class_="table-body__cell rankings-table__name name") 
s1

W1=[]
for i in s1:
    W1.append(i.text.replace('\n',''))

    
s2=soup.find_all('span',class_="table-body__logo-text")              

W2=[]
for i in s2:
    W2.append(i.text)


s3=soup.find_all('td',class_="table-body__cell rating")

W3=[]
for i in s3:
    W3.append(i.text)



H1=pd.DataFrame()
H1['PLAYER']=W1[0:10]

H2=pd.DataFrame()
H2['match']=W2[0:10]

H3=pd.DataFrame()
H3['rating']=W3[0:10]


pd.concat([H1,H2,H3.reindex(H1.index)], axis=1)
# Out:
#             PLAYER match rating
# 0      Virat Kohli   IND    844
# 1     Rohit Sharma   IND    813
# 2      Ross Taylor    NZ    801
# 3      Aaron Finch   AUS    779
# 4   Jonny Bairstow   ENG    775
# 5     David Warner   AUS    762
# 6  Quinton de Kock    SA    758
# 7        Shai Hope    WI    758
# 8  Kane Williamson    NZ    754
# 9     Fakhar Zaman   PAK    741

# %% [markdown]
# iii) Top 10 ODI bowlers along with the records of their team andrating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')

page.content

soup=BeautifulSoup(page.content)

s1=soup.find_all('td',class_="table-body__cell rankings-table__name name") 
s1

W1=[]
for i in s1:
    W1.append(i.text.replace('\n',''))


s2=soup.find_all('span',class_="table-body__logo-text")              

W2=[]
for i in s2:
    W2.append(i.text)


s3=soup.find_all('td',class_="table-body__cell rating")

W3=[]
for i in s3:
    W3.append(i.text)



H1=pd.DataFrame()
H1['PLAYER']=W1[0:10]

H2=pd.DataFrame()
H2['TEAM']=W2[0:10]

H3=pd.DataFrame()
H3['RATING']=W3[0:10]

pd.concat([H1,H2,H3.reindex(H1.index)], axis=1)
# Out:
#               PLAYER TEAM RATING
# 0     Josh Hazlewood  AUS    709
# 1   Mujeeb Ur Rahman  AFG    708
# 2       Chris Woakes  ENG    700
# 3       Mehedi Hasan  BAN    692
# 4         Matt Henry   NZ    691
# 5     Jasprit Bumrah  IND    679
# 6     Mitchell Starc  AUS    652
# 7    Shakib Al Hasan  BAN    650
# 8      Kagiso Rabada   SA    648
# 9  Mustafizur Rahman  BAN    640

# %% [markdown]
# # 6. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have toscrape:
# i) Top 10 ODI teams in women’s cricket along with the records for matches, points andrating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')

page.content

soup=BeautifulSoup(page.content)

s1=soup.find_all('span',class_="u-hide-phablet") 

W1=[]
for i in s1:
    W1.append(i.text.replace('\n',''))



s2=soup.find_all('td',class_="table-body__cell u-center-text")              

W21=[]
for i in s2:
    W21.append(i.text)

W2=W21[0:36:2]

s3=soup.find_all('td',class_="table-body__cell u-center-text")              

W31=[]
for i in s3:
    W31.append(i.text)


W3=W31[1:36:2]

s4=soup.find_all('td',class_="table-body__cell u-text-right rating")


W4=[]
for i in s4:
    W4.append(i.text)




H1=pd.DataFrame()
H1['TEAM']=W1[1:10]

H2=pd.DataFrame()
H2['MATCHES']=W2[0:10]

H3=pd.DataFrame()
H3['POINTS']=W3[0:10]

H4=pd.DataFrame()
H4['RATING']=W4[0:10]

pd.concat([H1,H2,H3,H4.reindex(H1.index)], axis=1)
# Out:
#            TEAM MATCHES POINTS RATING
# 0       England      20  2,370    119
# 1  South Africa      24  2,828    118
# 2         India      23  2,535    110
# 3   New Zealand      21  1,947     93
# 4   West Indies      17  1,427     84
# 5      Pakistan      20  1,496     75
# 6    Bangladesh       5    306     61
# 7     Sri Lanka      11    519     47
# 8       Ireland       2     25     13

# %% [markdown]
# ii) Top 10 women’s ODI players along with the records of their team and rating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')

page.content

soup=BeautifulSoup(page.content)

s1=soup.find_all('td',class_="table-body__cell rankings-table__name name") 

W1=[]
for i in s1:
    W1.append(i.text.replace('\n',''))



s2=soup.find_all('span',class_="table-body__logo-text")              

W2=[]
for i in s2:
    W2.append(i.text)



s4=soup.find_all('td',class_="table-body__cell rating")

W4=[]
for i in s4:
    W4.append(i.text)



H1=pd.DataFrame()
H1['PLAYER']=W1[0:10]

H2=pd.DataFrame()
H2['TEAM']=W2[0:10]

H4=pd.DataFrame()
H4['RATING']=W4[0:10]



pd.concat([H1,H2,H4.reindex(H1.index)], axis=1)
# Out:
#               PLAYER TEAM RATING
# 0        Lizelle Lee   SA    758
# 1       Alyssa Healy  AUS    756
# 2     Tammy Beaumont  ENG    754
# 3    Stafanie Taylor   WI    736
# 4        Meg Lanning  AUS    723
# 5  Amy Satterthwaite   NZ    715
# 6     Natalie Sciver  ENG    706
# 7    Smriti Mandhana  IND    701
# 8    Laura Wolvaardt   SA    683
# 9       Ellyse Perry  AUS    679

# %% [markdown]
# iii) Top 10 women’s ODI all-rounder along with the records of their team andrating

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')

page.content

soup=BeautifulSoup(page.content)

s1=soup.find_all('td',class_="table-body__cell rankings-table__name name") 

W1=[]
for i in s1:
    W1.append(i.text.replace('\n',''))

s2=soup.find_all('span',class_="table-body__logo-text")              

W2=[]
for i in s2:
    W2.append(i.text)

s4=soup.find_all('td',class_="table-body__cell rating")

W4=[]
for i in s4:
    W4.append(i.text)

H1=pd.DataFrame()
H1['PLAYER']=W1

H2=pd.DataFrame()
H2['TEAM']=W2

H4=pd.DataFrame()
H4['RATING']=W4

pd.concat([H1,H2,H4.reindex(H1.index)], axis=1)
# Out:
#                  PLAYER TEAM RATING
# 0          Ellyse Perry  AUS    418
# 1       Stafanie Taylor   WI    394
# 2        Natalie Sciver  ENG    365
# 3         Deepti Sharma  IND    331
# 4         Jess Jonassen  AUS    307
# 5      Ashleigh Gardner  AUS    252
# 6      Dane van Niekerk   SA    243
# 7         Sophie Devine   NZ    242
# 8       Katherine Brunt  ENG    239
# 9           Amelia Kerr   NZ    236
# 10      Hayley Matthews   WI    215
# 11       Jhulan Goswami  IND    215
# 12        Shikha Pandey  IND    195
# 13       Heather Knight  ENG    181
# 14         Rumana Ahmed  BAN    179
# 15             Nida Dar  PAK    176
# 16  Chamari Athapaththu   SL    164
# 17            Sune Luus   SA    153
# 18     Harmanpreet Kaur  IND    149

# %% [markdown]
# # 7. Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The

# %%
product_name=[]
price=[]
image_url=[]
ratings=[]
for i in range(1,21):
    page= requests.get("https://www.amazon.in/s?k=mobile+under+20000&page="+str(i)+"&qid=1629979374&ref=sr_pg_"+str(i), headers={"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36"})
    soup=BeautifulSoup(page.content)
    mobiles=soup.find_all("div",class_=["s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 AdHolder sg-col sg-col-12-of-16","s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col sg-col-12-of-16"])
    for mobile in mobiles:
        product_name.append(mobile.find("h2"))
        price.append(mobile.find("span",class_="a-price-whole"))
        image_url.append(mobile.find("img",class_="s-image").get('src'))
        ratings.append(mobile.find('span',class_="a-icon-alt"))

# %%
Products={'Product Name':product_name,'dPrice':price,'Image URL':image_url,'Average Rating':ratings}
df=pd.DataFrame(data=Products)
df
# Out:
#                                           Product Name    dPrice  \
# 0    [[[Samsung Galaxy M31s (Mirage Blue, 8GB RAM, ...  [16,999]
# 1    [[[Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 12...  [14,999]
# 2    [[[Redmi 9A (Nature Green, 2GB RAM, 32GB Stora...   [6,999]
# 3    [[[Redmi 9 Power (Mighty Black, 6GB RAM, 128GB...  [13,499]
# 4    [[[Samsung Galaxy M31 (Space Black, 6GB RAM, 1...  [14,999]
# ..                                                 ...       ...
# 421  [[[Samsung Galaxy M31s (Mirage Blue, 8GB RAM, ...  [16,999]
# 422  [[[Oppo F19 (Prism Black, 6GB RAM, 128GB Stora...  [18,990]
# 423  [[[Samsung Galaxy A12 (Blue, 6GB RAM, 128GB St...  [16,499]
# 424  [[[Samsung Galaxy M31 (Space Black, 6GB RAM, 1...  [14,999]
# 425  [[[OPPO A74 5G (Fluid Black,6GB RAM,128GB Stor...  [17,990]
#
#                                              Image URL        Average Rating
# 0    https://m.media-amazon.com/images/I/61d-phh4Gf...  [4.3 out of 5 stars]
# ...

# %% [markdown]
# # 8. Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended fore

# %%
page=requests.get('https://forecast.weather.gov/MapClick.php?w0=t&w1=td&w2=hi&w3=sfcwind&w4=sky&w5=pop&w6=rh&w7=rain&w8=thunder&AheadHour=0&&FcstType=text&textField1=37.7749&textField2=-122.4194&site=all')

page.content
soup=BeautifulSoup(page.content)

# %%
first=soup.find_all('div' , class_="col-sm-2 forecast-label")

# %%
first1=[]

for i in first:
    first1.append(i.text.replace('\n',''))
first1
# Out:
# ['Today',
#  'Tonight',
#  'Tuesday',
#  'Tuesday Night',
#  'Wednesday',
#  'Wednesday Night',
#  'Thursday',
#  'Thursday Night',
#  'Friday',
#  'Friday Night',
#  'Saturday',
#  'Saturday Night',
#  'Sunday']

# %%
first2=soup.find_all('div' , class_="col-sm-10 forecast-text")


first3=[]

for i in first2:
    first3.append(i.text.replace('\n',''))
first3
# Out:
# ['Sunny, with a high near 69. Breezy, with a west southwest wind 8 to 13 mph increasing to 17 to 22 mph in the afternoon. Winds could gust as high as 29 mph. ',
#  'Mostly clear, with a low around 56. West southwest wind 9 to 18 mph, with gusts as high as 23 mph. ',
#  'Sunny, with a high near 66. West southwest wind 9 to 14 mph increasing to 16 to 21 mph in the afternoon. Winds could gust as high as 28 mph. ',
#  'Partly cloudy, with a low around 55. Breezy, with a southwest wind 18 to 23 mph decreasing to 10 to 15 mph after midnight. Winds could gust as high as 31 mph. ',
#  'Mostly sunny, with a high near 64. West southwest wind 11 to 20 mph, with gusts as high as 25 mph. ',
#  'Partly cloudy, with a low around 54.',
#  'Mostly sunny, with a high near 66.',
#  'Partly cloudy, with a low around 54.',
#  'Mostly sunny, with a high near 66.',
#  'Partly cloudy, with a low around 55.',
#  'Mostly sunny, with a high near 67.',
#  'Partly cloudy, with a low around 56.',
# ...

# %%
H1=pd.DataFrame()

H1['WEATHER']=first3
print(H1)

H2=pd.DataFrame()

H2['DAY']=first1
print(H2)
# Out:
#                                               WEATHER
# 0   Sunny, with a high near 69. Breezy, with a wes...
# 1   Mostly clear, with a low around 56. West south...
# 2   Sunny, with a high near 66. West southwest win...
# 3   Partly cloudy, with a low around 55. Breezy, w...
# 4   Mostly sunny, with a high near 64. West southw...
# 5                Partly cloudy, with a low around 54.
# 6                  Mostly sunny, with a high near 66.
# 7                Partly cloudy, with a low around 54.
# 8                  Mostly sunny, with a high near 66.
# 9                Partly cloudy, with a low around 55.
# 10                 Mostly sunny, with a high near 67.
# 11               Partly cloudy, with a low around 56.
# 12                        Sunny, with a high near 72.
#                 DAY
# 0             Today
# 1           Tonight
# 2           Tuesday
# 3     Tuesday Night
# 4         Wednesday
# 5   Wednesday Night
# 6          Thursday
# 7    Thursday Night
# ...

# %%
result=pd.concat([H2,H1.reindex(H2.index)], axis=1)
print(result)
# Out:
#                 DAY                                            WEATHER
# 0             Today  Sunny, with a high near 69. Breezy, with a wes...
# 1           Tonight  Mostly clear, with a low around 56. West south...
# 2           Tuesday  Sunny, with a high near 66. West southwest win...
# 3     Tuesday Night  Partly cloudy, with a low around 55. Breezy, w...
# 4         Wednesday  Mostly sunny, with a high near 64. West southw...
# 5   Wednesday Night               Partly cloudy, with a low around 54.
# 6          Thursday                 Mostly sunny, with a high near 66.
# 7    Thursday Night               Partly cloudy, with a low around 54.
# 8            Friday                 Mostly sunny, with a high near 66.
# 9      Friday Night               Partly cloudy, with a low around 55.
# 10         Saturday                 Mostly sunny, with a high near 67.
# 11   Saturday Night               Partly cloudy, with a low around 56.
# ...

# %% [markdown]
# # 9. Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title, company name, CTC, and apply date.

# %%
page=requests.get("https://internshala.com/fresher-jobs")

page.content

soup=BeautifulSoup(page.content)

# %% [markdown]
# job

# %%
job=soup.find_all('div',class_="heading_4_5 profile")
s1=[]

for i in job:
    s1.append(i.text.replace('\n',''))

H1=pd.DataFrame()

H1['job']=s1[:10]    
H1
# Out:
#                                                  job
# 0                                 OMNI SPORT LEADER
# 1         Executive/Senior Executive - Partnerships
# 2                                 Executive - Sales
# 3                       Junior Operations Executive
# 4                           Associate Web Developer
# 5                     Engineering Admissions Writer
# 6  Assistant Manager - Product Development & Prog...
# 7                       Junior Full Stack Developer
# 8                                  Strategy Analyst
# 9                               Associate Recruiter

# %% [markdown]
#  company

# %%
company=soup.find_all('div',class_="heading_6 company_name")
s2=[]

for i in company:
    s2.append(i.text.replace('\n',''))
H2=pd.DataFrame()

H2['company']=s2[:10]            #[:10] meaning is for top 10 no need always
H2
# Out:
#                                              company
# 0                          Decathlon Sport India ...
# 1                          Freecharge Payments Te...
# 2                          Freecharge Payments Te...
# 3                          Freecharge Payments Te...
# 4                          WebMOBI               ...
# 5                          GREedge               ...
# 6                          SUPROS                ...
# 7                          Techdome Solutions Pri...
# 8                          RedCarpetUp           ...
# 9                          Talhive               ...

# %% [markdown]
# ctc

# %%
ctc=soup.find_all('div',class_="other_detail_item_row")#,class__="item_heading")
s3=[]

for i in ctc:
    s3.append(i.text.replace('\n',''))
s3
# Out:
# ['                                Start date                            Starts\xa0Immediately                        CTC  3 - 4 LPA                                                    ',
#  "Apply By18 Sep' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 4.2 LPA                                                    ',
#  "Apply By11 Sep' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 3.5 LPA                                                    ',
#  "Apply By11 Sep' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 4 LPA                                                    ',
#  "Apply By4 Sep' 21",
# ...

# %%
H3=pd.DataFrame()

H3['last date']=s3[:10]

# %%
last_date=soup.find_all('div',class_="other_detail_item")#    "item_body")

s4=[]

for i in last_date:
    for j in range(1,20,2):
        s4.append(j)#.replace('\n',''))#.replace('Starts\xa0Immediately ', ''))
s4


H4=pd.DataFrame()

H4['ctc']=s4[:10]            #[:10] meaning is for top 10 no need always

# %% [markdown]
# result

# %%
result=pd.concat([H1,H2,H3,H4.reindex(H1.index)], axis=1)
result
# Out:
#                                                  job  \
# 0                                 OMNI SPORT LEADER
# 1         Executive/Senior Executive - Partnerships
# 2                                 Executive - Sales
# 3                       Junior Operations Executive
# 4                           Associate Web Developer
# 5                     Engineering Admissions Writer
# 6  Assistant Manager - Product Development & Prog...
# 7                       Junior Full Stack Developer
# 8                                  Strategy Analyst
# 9                               Associate Recruiter
#
#                                              company  \
# 0                          Decathlon Sport India ...
# 1                          Freecharge Payments Te...
# 2                          Freecharge Payments Te...
# 3                          Freecharge Payments Te...
# 4                          WebMOBI               ...
# 5                          GREedge               ...
# ...

# %% [markdown]
# # 10. Write a python program to scrape house details from https://www.nobroker.in/ for any location. It should include house title, location, area, emi and price

# %%
page=requests.get("https://www.nobroker.in/property/sale/mumbai/Goregaon%20West?searchParam=W3sibGF0IjoxOS4xNjM1NzkzLCJsb24iOjcyLjg0NTg4MDQsInBsYWNlSWQiOiJDaElKRVhfU2dWQzI1enNSNHo1R2FjRzYzYU0iLCJwbGFjZU5hbWUiOiJHb3JlZ2FvbiBXZXN0In1d&radius=2.0&type=RK1,BHK1,BHK2,BHK3,BHK4,BHK4PLUS&propertyAge=0")

# %%
page.content

soup=BeautifulSoup(page.content)

house=soup.find_all('span',itemprop="name")                  

s=[]

for i in house:
    s.append(i.text.replace('\n',''))

H1=pd.DataFrame()

H1['House']=s[2:12]             #[:10] meaning is for top 10 no need always

# %%
# location

# %%
f2=soup.find_all('div',class_="nb__2CMjv")

s1=[]

for i in f2:
    s1.append(i.text.replace('\n','')) 


import pandas as pd

H3=pd.DataFrame()

H3['location']=s1             #[:10] meaning is for top 10 no need always

# %%
# AREA

# %%
f3=soup.find_all('div',class_="nb__3oNyC")

s3=[]

for i in f3:
    s3.append(i.text.replace('\n',''))

H2=pd.DataFrame()

H2['AREA']=s3[:12]            #[:10] meaning is for top 10 no need always

# %%
result=pd.concat([H1,H2,H3.reindex(H1.index)], axis=1)
result
# Out:
#                                                House        AREA  \
# 0  2 BHK Flat  For Sale  In Ankur Chs In Andheri ...    630 sqft
# 1  2 BHK Flat  For Sale  In Ankur Chs In Andheri ...    620 sqft
# 2  Bori Colony, Kadam Wadi, Marol, Andheri East, ...  1,180 sqft
# 3  1 BHK Apartment  For Sale  In Ekta Suprabhat I...  1,300 sqft
# 4  1 BHK Flat  For Sale  In Ekta Suprabhat In Gor...  1,250 sqft
# 5  Rd Number 16 Siddharth Nagar, Goregaon West Mu...  1,590 sqft
# 6  3 BHK Flat  For Sale  In Galaxy Heights In Gor...  1,221 sqft
# 7  3 BHK Flat  For Sale  In Galaxy Heights In Gor...    510 sqft
# 8  Near Bangur Nagar Signal, New Link Road,  near...    880 sqft
# 9  2 BHK Apartment  For Sale  In Raj Spaces In Go...    775 sqft
#
#                                             location
# 0  Bori Colony, Kadam Wadi, Marol, Andheri East, ...
# 1  Ekta Suprabhat  Rd Number 16 Siddharth Nagar, ...
# 2  Near Bangur Nagar Signal, New Link Road,  near...
# ...
